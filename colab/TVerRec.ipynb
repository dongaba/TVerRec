# %%
# Update the list of packages
# !sudo apt-get update
# Install pre-requisite packages.
# !sudo apt-get install -y wget apt-transport-https software-properties-common git
# Download the Microsoft repository GPG keys
# !wget -q "https://packages.microsoft.com/config/ubuntu/$(lsb_release -rs)/packages-microsoft-prod.deb"
# Register the Microsoft repository GPG keys
# !sudo dpkg -i packages-microsoft-prod.deb
# !rm -rf packages-microsoft-prod.deb*
# Update the list of packages after we added packages.microsoft.com
# !sudo apt-get update
# Install PowerShell
# !sudo apt-get install -y powershell git
# Version up if available
#!sudo apt-get upgrade

# Confirm PowerShell
#!which pwsh

# git clone
# !ls -la /content
# !pwd
# !if [ ! -d /content/TVerRec ]; then git clone https://github.com/dongaba/TVerRec ; else cd /content/TVerRec && git pull && cd - ; fi
# !chmod a+x /content/TVerRec/unix/*.sh

# setting for Colab
# !sed -i -e "s|\.\./src|/content/TVerRec/src|g" /content/TVerRec/unix/*.sh
# !sed -i -e "s|'W:'|'/content/drive/MyDrive/Work'|g" /content/TVerRec/conf/system_setting.ps1
# !sed -i -e "s|\$env:TMP|'/tmp'|g" /content/TVerRec/conf/system_setting.ps1
# !sed -i -e "s|''|'/content/drive/MyDrive/Save'|g" /content/TVerRec/conf/system_setting.ps1

# !/content/TVerRec/unix/start_tverrec.sh
# Out:
# Hit:1 http://security.ubuntu.com/ubuntu focal-security InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu focal-cran40/ InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  InRelease
# Hit:4 https://packages.microsoft.com/ubuntu/20.04/prod focal InRelease
# Hit:5 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu focal InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu focal InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu focal-updates InRelease
# Hit:8 http://ppa.launchpad.net/cran/libgit2/ubuntu focal InRelease
# Hit:9 http://archive.ubuntu.com/ubuntu focal-backports InRelease
# Hit:10 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu focal InRelease
# Hit:11 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu focal InRelease
# Hit:12 http://ppa.launchpad.net/ubuntugis/ppa/ubuntu focal InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# git is already the newest version (1:2.25.1-1ubuntu3.10).
# software-properties-common is already the newest version (0.99.9.11).
# wget is already the newest version (1.20.3-1ubuntu2).
# apt-transport-https is already the newest version (2.0.9).
# 0 upgraded, 0 newly installed, 0 to remove and 28 not upgraded.
# (Reading database ... 123220 files and directories currently installed.)
# Preparing to unpack packages-microsoft-prod.deb ...
# Unpacking packages-microsoft-prod (1.0-ubuntu20.04.1) over (1.0-ubuntu20.04.1) ...
# Setting up packages-microsoft-prod (1.0-ubuntu20.04.1) ...
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu focal-cran40/ InRelease
# Hit:2 https://packages.microsoft.com/ubuntu/20.04/prod focal InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  InRelease
# Hit:4 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu focal InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu focal InRelease
# Hit:6 http://security.ubuntu.com/ubuntu focal-security InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu focal-updates InRelease
# Hit:8 http://ppa.launchpad.net/cran/libgit2/ubuntu focal InRelease
# Hit:9 http://archive.ubuntu.com/ubuntu focal-backports InRelease
# Hit:10 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu focal InRelease
# Hit:11 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu focal InRelease
# Hit:12 http://ppa.launchpad.net/ubuntugis/ppa/ubuntu focal InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# git is already the newest version (1:2.25.1-1ubuntu3.10).
# powershell is already the newest version (7.3.4-1.deb).
# 0 upgraded, 0 newly installed, 0 to remove and 28 not upgraded.
# total 28
# drwxr-xr-x  1 root root 4096 Apr 29 22:35 .
# drwxr-xr-x  1 root root 4096 Apr 29 22:26 ..
# drwxr-xr-x  4 root root 4096 Apr 27 13:34 .config
# drwx------  5 root root 4096 Apr 29 22:33 drive
# -rw-r--r--  1 root root    5 Apr 29 22:33 pid-a5fad32f9bcb.txt
# drwxr-xr-x  1 root root 4096 Apr 27 13:35 sample_data
# drwxr-xr-x 16 root root 4096 Apr 29 22:33 TVerRec
# /content
# Already up to date.
# /content
# ===
# ===========================================================================
#
#         ████████ ██    ██ ███████ ██████  ██████  ███████  ██████
#            ██    ██    ██ ██      ██   ██ ██   ██ ██      ██
#            ██    ██    ██ █████   ██████  ██████  █████   ██
#            ██     ██  ██  ██      ██   ██ ██   ██ ██      ██
#            ██      ████   ███████ ██   ██ ██   ██ ███████  ██████
#
#         TVerRec : TVerダウンローダ
#                              一括ダウンロード version. 2.7.1 beta 1
#
# ===========================================================================
#
# =youtube-dlは最新です。
# 　youtube-dl current: 2023.03.04
# 　youtube-dl latest: 2023.03.04
#
# ===ffmpegは最新です。
# 　ffmpeg current: 6.0
# 　ffmpeg latest: 6.0
#
# ダウンロードの終了を待機しています
# ---------------------------------------------------------------------------
# 処理を終了しました。
# ---------------------------------------------------------------------------
# ===----------------------------------------------------------------------
# 処理が中断した際にできたゴミファイルを削除します
# ----------------------------------------------------------------------
# /content/TVerRec/db - ffmpeg_error_*.log
# /content/TVerRec/src - brightcovenew_*.lock
# /content/TVerRec/conf - ignore.conf.*
# /tmp - *.ytdl
# /tmp - *.jpg
# /tmp - *.vtt
# /tmp - *.temp.mp4
# /tmp - *.part
# /tmp - *.mp4.part-Frag*
# /tmp - *.mp4
# /content/drive/MyDrive/Work - *.ytdl
# /content/drive/MyDrive/Work - *.jpg
# /content/drive/MyDrive/Work - *.vtt
# /content/drive/MyDrive/Work - *.temp.mp4
# /content/drive/MyDrive/Work - *.part
# /content/drive/MyDrive/Work - *.mp4.part-Frag*
# /content/drive/MyDrive/Save - *.ytdl
# /content/drive/MyDrive/Save - *.jpg
# /content/drive/MyDrive/Save - *.vtt
# /content/drive/MyDrive/Save - *.temp.mp4
# /content/drive/MyDrive/Save - *.part
# /content/drive/MyDrive/Save - *.mp4.part-Frag*
# ----------------------------------------------------------------------
# ダウンロード対象外の番組を削除します
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 空ディレクトリを削除します
# ----------------------------------------------------------------------
# 　ディレクトリを見つけられませんでした
# =====ffmpegは最新です。
# 　ffmpeg current: 6.0
# 　ffmpeg latest: 6.0
#
# ----------------------------------------------------------------------
# ダウンロード履歴の不整合レコードを削除します
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# 30日以上前に処理したものはダウンロード履歴から削除します
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# ダウンロード履歴の重複レコードを削除します
# ----------------------------------------------------------------------
# 　ダウンロード履歴の更新に失敗しました
#
# ----------------------------------------------------------------------
# 整合性検証が終わっていない番組を検証します
# ----------------------------------------------------------------------
# 　すべての番組を検証済です
#
# ----------------------------------------------------------------------
# ダウンロード履歴から検証が終わっていない番組のステータスを変更します
# ----------------------------------------------------------------------
#
# ======ffmpegは最新です。
# 　ffmpeg current: 6.0
# 　ffmpeg latest: 6.0
#
# ----------------------------------------------------------------------
# ダウンロード履歴の不整合レコードを削除します
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# 30日以上前に処理したものはダウンロード履歴から削除します
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# ダウンロード履歴の重複レコードを削除します
# ----------------------------------------------------------------------
# 　ダウンロード履歴の更新に失敗しました
#
# ----------------------------------------------------------------------
# 整合性検証が終わっていない番組を検証します
# ----------------------------------------------------------------------
# 　すべての番組を検証済です
#
# ----------------------------------------------------------------------
# ダウンロード履歴から検証が終わっていない番組のステータスを変更します
# ----------------------------------------------------------------------
#
# ===----------------------------------------------------------------------
# 移動先ディレクトリの一覧を作成しています
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# ダウンロードファイルを移動しています
# ----------------------------------------------------------------------
# ===----------------------------------------------------------------------
# 処理が中断した際にできたゴミファイルを削除します
# ----------------------------------------------------------------------
# /content/TVerRec/db - ffmpeg_error_*.log
# /content/TVerRec/src - brightcovenew_*.lock
# /content/TVerRec/conf - ignore.conf.*
# /tmp - *.ytdl
# /tmp - *.jpg
# /tmp - *.vtt
# /tmp - *.temp.mp4
# /tmp - *.part
# /tmp - *.mp4.part-Frag*
# /tmp - *.mp4
# /content/drive/MyDrive/Work - *.ytdl
# /content/drive/MyDrive/Work - *.jpg
# /content/drive/MyDrive/Work - *.vtt
# /content/drive/MyDrive/Work - *.temp.mp4
# /content/drive/MyDrive/Work - *.part
# /content/drive/MyDrive/Work - *.mp4.part-Frag*
# /content/drive/MyDrive/Save - *.ytdl
# /content/drive/MyDrive/Save - *.jpg
# /content/drive/MyDrive/Save - *.vtt
# /content/drive/MyDrive/Save - *.temp.mp4
# /content/drive/MyDrive/Save - *.part
# /content/drive/MyDrive/Save - *.mp4.part-Frag*
# ----------------------------------------------------------------------
# ダウンロード対象外の番組を削除します
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 空ディレクトリを削除します
# ----------------------------------------------------------------------
# 　ディレクトリを見つけられませんでした
# 3600 秒待機します。すぐに処理を再開するにはEnterを押してください。
# ^C
